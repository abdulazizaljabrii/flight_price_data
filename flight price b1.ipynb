# %% [markdown]
# # Importing the libraries :

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Data Loading and Initial Exploration :

# %%
df = pd.read_csv('/Users/azozaljabri/Desktop/archive-2/Clean_Dataset.csv')
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("Data types of columns:")
print(df.dtypes)
# Out:
# Number of rows: 300153
# Number of columns: 12
# Data types of columns:
# Unnamed: 0            int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
df.head(10)
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
# 5           5   Vistara   UK-945       Delhi        Morning  zero
# 6           6   Vistara   UK-927       Delhi        Morning  zero
# 7           7   Vistara   UK-951       Delhi      Afternoon  zero
# 8           8  GO_FIRST   G8-334       Delhi  Early_Morning  zero
# 9           9  GO_FIRST   G8-336       Delhi      Afternoon  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# ...

# %%
df.tail(10)
# Out:
#         Unnamed: 0    airline  flight source_city departure_time stops  \
# 300143      300143  Air_India  AI-440     Chennai  Early_Morning   one
# 300144      300144  Air_India  AI-539     Chennai        Evening   one
# 300145      300145  Air_India  AI-430     Chennai        Morning   one
# 300146      300146  Air_India  AI-440     Chennai  Early_Morning   one
# 300147      300147  Air_India  AI-569     Chennai  Early_Morning   one
# 300148      300148    Vistara  UK-822     Chennai        Morning   one
# 300149      300149    Vistara  UK-826     Chennai      Afternoon   one
# 300150      300150    Vistara  UK-832     Chennai  Early_Morning   one
# 300151      300151    Vistara  UK-828     Chennai  Early_Morning   one
# 300152      300152    Vistara  UK-822     Chennai        Morning   one
#
#        arrival_time destination_city     class  duration  days_left  price
# 300143        Night        Hyderabad  Business     17.42         49  51345
# ...

# %%
df.sample(10)
# Out:
#         Unnamed: 0    airline   flight source_city departure_time  \
# 48193        48193    AirAsia   I5-767      Mumbai  Early_Morning
# 87015        87015    Vistara   UK-864   Bangalore        Evening
# 60477        60477     Indigo   6E-825      Mumbai          Night
# 39572        39572   SpiceJet  SG-8645       Delhi        Evening
# 86054        86054    Vistara   UK-854   Bangalore        Evening
# 77768        77768  Air_India   AI-888      Mumbai        Evening
# 236871      236871  Air_India   AI-867      Mumbai          Night
# 73716        73716    Vistara   UK-613      Mumbai      Afternoon
# 233983      233983    Vistara   UK-960      Mumbai        Morning
# 116638      116638    Vistara   UK-810   Bangalore  Early_Morning
#
#               stops arrival_time destination_city     class  duration  \
# 48193          zero      Morning            Delhi   Economy      2.17
# 87015           one   Late_Night            Delhi   Economy      5.17
# ...

# %% [markdown]
# # 2. Data Cleaning :

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df['airline'].value_counts()
# Out:
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: airline, dtype: int64

# %%
df.drop_duplicates().sum()
# Out:
# Unnamed: 0                                                45045761628
# airline             SpiceJetSpiceJetAirAsiaVistaraVistaraVistaraVi...
# flight              SG-8709SG-8157I5-764UK-995UK-963UK-945UK-927UK...
# source_city         DelhiDelhiDelhiDelhiDelhiDelhiDelhiDelhiDelhiD...
# departure_time      EveningEarly_MorningEarly_MorningMorningMornin...
# stops               zerozerozerozerozerozerozerozerozerozerozeroze...
# arrival_time        NightMorningEarly_MorningAfternoonMorningAfter...
# destination_city    MumbaiMumbaiMumbaiMumbaiMumbaiMumbaiMumbaiMumb...
# class               EconomyEconomyEconomyEconomyEconomyEconomyEcon...
# duration                                                   3668176.06
# days_left                                                     7805404
# price                                                      6270094275
# dtype: object

# %%
df['source_city'].value_counts()
# Out:
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: source_city, dtype: int64

# %%
df['departure_time'].value_counts()
# Out:
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: departure_time, dtype: int64

# %% [markdown]
# # 3. Exploratory Data Analysis :

# %%
sns.histplot(data=df, x='source_city', hue='class', multiple='stack')


plt.xlabel('Source City')
plt.ylabel('Count')
plt.title('Histogram of Source City by Class')


plt.show()

# %%
airline_counts = df['airline'].value_counts()

sns.barplot(x=airline_counts.index, y=airline_counts.values, color='steelblue')

plt.xticks(rotation=90)
plt.xlabel('Airline')
plt.ylabel('Count')
plt.title('Most Frequently Used Airlines')
plt.show()

# %%
departure_time = df['departure_time'].value_counts()

sns.barplot(x=departure_time.index, y=departure_time.values, color='steelblue')

plt.xticks(rotation=90)
plt.xlabel('Departure Time')
plt.ylabel('Count')
plt.title('Most Common Departure Times')
plt.show()

# %%
sns.countplot(data=df, x='source_city', color='steelblue')

plt.xticks(rotation=45)
plt.xlabel('Source City')
plt.ylabel('Count')
plt.title('Count Plot of Source Cities')

plt.show()

# %%
arrival_cities = df['destination_city'].value_counts()


sorted_arrival_cities = arrival_cities.sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='destination_city', order=sorted_arrival_cities.index, color='steelblue')

plt.xticks(rotation=45)
plt.xlabel('Arrival City')
plt.ylabel('Count')
plt.title('Count of Arrival Cities')

plt.show()

# %%
avg_price_by_city = df.groupby('destination_city')['price'].mean().reset_index()

# Sort the DataFrame based on the 'price' column in descending order
avg_price_by_city = avg_price_by_city.sort_values('price', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=avg_price_by_city, x='destination_city', y='price', color='steelblue')

plt.xticks(rotation=45)
plt.xlabel('Destination City')
plt.ylabel('Average Price')
plt.title('Average Price by Destination City')

plt.show()

# %%
economy_df = df[df['class'] == 'Economy']

avg_price_by_stop = economy_df.groupby('stops')['price'].mean().reset_index()

# Sort the DataFrame based on the 'price' column in descending order
avg_price_by_stop = avg_price_by_stop.sort_values('price', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=avg_price_by_stop, x='stops', y='price', color='steelblue')

plt.xticks(rotation=45)
plt.xlabel('Stops')
plt.ylabel('Average Price')
plt.title('Average Price by Stops (Economy Class)')

plt.show()

# %%
Business_df = df[df['class'] == 'Business']

avg_price_by_stop = Business_df.groupby('stops')['price'].mean().reset_index()

# Sort the DataFrame based on the 'price' column in descending order
avg_price_by_stop = avg_price_by_stop.sort_values('price', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=avg_price_by_stop, x='stops', y='price', color='steelblue')

plt.xticks(rotation=45)
plt.xlabel('Stops')
plt.ylabel('Average Price')
plt.title('Average Price by Stops (Business Class)')

plt.show()

# %%
avg_price_by_city = df.groupby('airline')['price'].mean().reset_index()

avg_price_by_city = avg_price_by_city.sort_values('price', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=avg_price_by_city, x='airline', y='price', color='steelblue')

plt.xticks(rotation=45)
plt.xlabel('Airline')
plt.ylabel('Average Price')
plt.title('Average Price by Airline')

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='duration', y='price', color='steelblue')

plt.xlabel('Duration')
plt.ylabel('Price')
plt.title('Price vs Duration')

plt.show()

# %% [markdown]
# # 4. Feature Engineering:

# %%
df = df.drop(columns='days_left')

# %%
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  price
# ...
